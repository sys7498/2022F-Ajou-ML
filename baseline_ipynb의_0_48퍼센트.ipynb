# %% [markdown]
# <a href="https://colab.research.google.com/github/sys7498/2022F-Ajou-ML/blob/main/baseline_ipynb%EC%9D%98_0_48%ED%8D%BC%EC%84%BC%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge :: Coin Classification

# %% [markdown]
# 여러 나라의 동전 이미지를 보고 어느 나라의 동전인지 분류하는 테스크입니다.
# 동전의 클래스는 인도, 유럽, 중국, 미국, 일본, 필리핀으로 총 6개 입니다.

# %% [markdown]
# 각 나라의 label은 아래와 같이 설정합니다.
# {'china_coins': 0,
#  'euro_coins': 1,
#  'indian_coins': 2,
#  'peso_coins': 3,
#  'us_coins': 4,
#  'yen_coins': 5}

# %% [markdown]
# ## Drive에서 데이터 가져오기 OR 로컬에서 파일 업로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
cd drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
#  2018013190_김도연_week12.ipynb            net_pretrained.pth
# '2018013190_김도연_week13 (1) (1).ipynb'   new/
# '2018013190_김도연_week13 (1).ipynb'       new_crawl/
#  2018013190_김도연_week13.ipynb            not_crawled_summoners.csv
# '2018013190_김도연_week6 (1) (1).ipynb'    prediction_result.csv
# '2018013190_김도연_week6 (1).ipynb'        Student_Marks.csv
#  2018013190_김도연_week9.ipynb             train-1.csv
#  asdfasf.ipynb                             train.csv
#  baseline.ipynb                            train_data.csv
#  coins_images/                             Training.ipynb
#  crawling.ipynb                           'Untitled0 (1).ipynb'
# 'HW3.ipynb의 사본'                        'Untitled0 (2).ipynb'
# 'HW3.ipynb의 사본 (1)'                     Untitled0.ipynb
# 'HW3.ipynb의 사본 (2)'                    'Untitled1 (1).ipynb'
#  김도연좀해라.ipynb                        Untitled1.ipynb
#  kaggle_score.csv                          Untitled2.ipynb
#  leaders.csv                               Untitled3.ipynb
#  mmmm.ipynb                                Untitled4.ipynb
#  mushrooms-1.csv

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, utils, datasets
from torch.utils.data import Dataset, DataLoader
import torch.utils.data

import gc
gc.collect()
torch.cuda.empty_cache()

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True # prevent truncate error

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        #transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
        


        
    ]),
    "test": transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        #transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
        
    ])
}

# %%
# From https://gist.github.com/andrewjong/6b02ff237533b3b2c554701fb53d5c4d

class ImageFolderWithPaths(datasets.ImageFolder):
    """Custom dataset that includes image file paths. Extends
    torchvision.datasets.ImageFolder
    """

    # override the __getitem__ method. this is the method that dataloader calls
    def __getitem__(self, index):
        # this is what ImageFolder normally returns 
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        # the image file path
        path = self.imgs[index][0]
        # make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path

# %%
train_data = ImageFolderWithPaths(root = './coins_images/' + "TRAIN", # load train data
                                   transform = image_transforms['train'],
                                  )
train_loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True) # make train loader

# %%
train_data
# Out:
# Dataset ImageFolderWithPaths
#     Number of datapoints: 1229
#     Root location: ./coins_images/TRAIN
#     StandardTransform
# Transform: Compose(
#                Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=None)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %%
classes = train_data.class_to_idx # class name
classes
# Out:
# {'china_coins': 0,
#  'euro_coins': 1,
#  'indian_coins': 2,
#  'peso_coins': 3,
#  'us_coins': 4,
#  'yen_coins': 5}

# %% [markdown]
# ## Show Example Data

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
# print(dataiter.next())
images, labels, paths = next(dataiter)

batch_size = 16

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print()
labels = labels.tolist()
print(' '.join(f'{list(classes.keys())[list(classes.values()).index(j)]}' for j in labels))
# Out:
# indian_coins china_coins euro_coins indian_coins euro_coins china_coins euro_coins us_coins china_coins china_coins us_coins euro_coins indian_coins indian_coins yen_coins euro_coins

# %% [markdown]
# ## Define a Convolutional Neural Network

# %% [markdown]
# Modified https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
from torch.nn.modules import padding
class Net(nn.Module):
    '''def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 12, 5)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(12, 48, 3)
        self.fc1 = nn.Linear(48 * 148 * 148, 600) # in_features, out_features ((((((600-5)+1)/2)/2)-5)+1)/2
        self.fc2 = nn.Linear(600, 54)
        self.fc3 = nn.Linear(54, 6)

    def forward(self, input):
      output = F.relu(self.conv1(input))
      output = self.pool(output)
      output = F.relu(self.conv2(output))
      output = self.pool(output)
      output = torch.flatten(output, 1) # flatten all dimensions except batch
      output = F.relu(self.fc1(output))
      output = F.relu(self.fc2(output))
      output = self.fc3(output)

      return output'''
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 12, kernel_size=3, padding=1),
            nn.BatchNorm2d(12),
            nn.ReLU(),
            nn.Conv2d(12, 36, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(36),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 64 x 64 x 64

            nn.Conv2d(36, 72, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(72),
            nn.ReLU(),
            nn.Conv2d(72, 144, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(144),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 128 x 32 x 32

            nn.Conv2d(144, 288, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(288),
            nn.ReLU(),
            nn.Conv2d(288, 288, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(288),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 256 x 16 x 16

            nn.Conv2d(288, 576, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(576),
            nn.ReLU(),
            nn.Conv2d(576, 576, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(576),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 576 x 8 x 8

            nn.Conv2d(576, 1152, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(1152),
            nn.ReLU(),
            nn.Conv2d(1152, 1152, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(1152),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 1152 x 4 x 4


            nn.Flatten(), 
            #nn.Dropout(0.2),
            nn.Linear(1152*4*4, 2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Linear(1024, 6))
        
    def forward(self, xb):
        return self.network(xb)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Use GPU if it's available # colab 런타임 유형 변경에서 GPU 선택할 것

# %%
net = Net() # define the network
net = net.to(device) # send the network to the device

# %% [markdown]
# ## Define a Loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss() # loss function, 변경 가능
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9) # optimizer, 변경 가능
#optimizer = optim.Adam(net.parameters(), lr=0.05) # optimizer, 변경 가능

# %% [markdown]
# ## Train the Network

# %%
for epoch in range(50):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(tqdm(train_loader, 0)):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels, paths = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 50 == 49:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0

print('Finished Training') # epoch이 50일 때, training acc 46% 달성
# Out:
#   0%|          | 0/77 [00:00<?, ?it/s]
# [1,    50] loss: 0.026
#   0%|          | 0/77 [00:00<?, ?it/s]
# [2,    50] loss: 0.020
#   0%|          | 0/77 [00:00<?, ?it/s]
# [3,    50] loss: 0.015
#   0%|          | 0/77 [00:00<?, ?it/s]
# [4,    50] loss: 0.012
#   0%|          | 0/77 [00:00<?, ?it/s]
# [5,    50] loss: 0.009
#   0%|          | 0/77 [00:00<?, ?it/s]
# [6,    50] loss: 0.008
#   0%|          | 0/77 [00:00<?, ?it/s]
# [7,    50] loss: 0.008
#   0%|          | 0/77 [00:00<?, ?it/s]
# [8,    50] loss: 0.004
#   0%|          | 0/77 [00:00<?, ?it/s]
# [9,    50] loss: 0.005
#   0%|          | 0/77 [00:00<?, ?it/s]
# [10,    50] loss: 0.002
#   0%|          | 0/77 [00:00<?, ?it/s]
# [11,    50] loss: 0.002
#   0%|          | 0/77 [00:00<?, ?it/s]
# [12,    50] loss: 0.004
#   0%|          | 0/77 [00:00<?, ?it/s]
# [13,    50] loss: 0.003
#   0%|          | 0/77 [00:00<?, ?it/s]
# [14,    50] loss: 0.001
#   0%|          | 0/77 [00:00<?, ?it/s]
# [15,    50] loss: 0.001
#   0%|          | 0/77 [00:00<?, ?it/s]
# [16,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [17,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [18,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [19,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [20,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [21,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [22,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [23,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [24,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [25,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [26,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [27,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [28,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [29,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [30,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [31,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [32,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [33,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [34,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [35,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [36,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [37,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [38,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [39,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [40,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [41,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [42,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [43,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [44,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [45,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [46,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [47,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [48,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [49,    50] loss: 0.000
#   0%|          | 0/77 [00:00<?, ?it/s]
# [50,    50] loss: 0.000
# Finished Training

# %% [markdown]
# ## Save the Network

# %%
# save the trained model
PATH = './net_pretrained.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# ## Load the Network

# %%
net = Net()
net = net.to(device)
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Calculate Training accuracy

# %%
train_test_loader = torch.utils.data.DataLoader(train_data, batch_size=1, shuffle=False) # make train_test loader

images = images.to(device)
print(images.is_cuda)
# Out:
# True

# %%
correct = 0
total = 0

image_id = []
predicted_label = []
with torch.no_grad(): # since we're not training, we don't need to calculate the gradients for our outputs
    for i, data in enumerate(tqdm(train_test_loader,0)):
        images, labels, paths = data
        images = images.to(device)
        labels = labels.to(device)
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        
        image_id.append(paths)
        predicted_label.append(predicted.item())

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # print('path:', paths, 'predicted_label:', predicted)
print(f'Accuracy of the network on the {len(train_test_loader.dataset)} test images: {100 * correct // total} %')
# Out:
#   0%|          | 0/1229 [00:00<?, ?it/s]
# Accuracy of the network on the 1229 test images: 86 %

# %% [markdown]
# ## Testing & Making a Submission File

# %%
from PIL import Image
import torch
from torch.utils.data import Dataset
import os


class testDataset(Dataset):
    def __init__(self, data_dir, transform):
        # path to images
        path2data = os.path.join(data_dir)

        # get a list of images
        filenames = os.listdir(path2data)

        # get the full path to images
        self.full_filenames = [os.path.join(path2data, f) for f in filenames]
        
        # set transformations
        self.transform = transform

    def __len__(self):
        # return size of dataset
        return len(self.full_filenames)

    def __getitem__(self, idx):
        # open image, apply transforms and return with label
        image = Image.open(self.full_filenames[idx])
        image = self.transform(image)
        image_name = self.full_filenames[idx]
        return image, image_name

# %%
test_data = testDataset('coins_images/TEST/',image_transforms['test'])
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False) # ALWAYS SET SHUFFLE FALSE

# %%
image_id = []
predicted_label = []
with torch.no_grad(): # since we're not training, we don't need to calculate the gradients for our outputs
    for i, data in enumerate(tqdm(test_loader,0)):
        images, paths = data
        images = images.to(device)

        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        path = os.path.basename(paths[0])
        image_id.append(path)
        predicted_label.append(predicted.item())
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]

# %%
predicted_df = pd.DataFrame({'image_id': image_id, 'predicted_label': predicted_label})

# %%
predicted_df['predicted_label'] = predicted_df.predicted_label.astype(str)

# %%
predicted_df.to_csv('prediction_result.csv', index=False)

# %%
score = pd.read_csv('./kaggle_score.csv', encoding='utf-8')

# %%
score.head
# Out:
# <bound method NDFrame.head of          image_id  predicted_label
# 0    test_106.jpg                1
# 1    test_114.jpg                1
# 2     test_29.jpg                0
# 3     test_34.jpg                0
# 4     test_40.jpg                2
# ..            ...              ...
# 115   test_83.jpg                2
# 116   test_95.jpg                2
# 117   test_96.jpg                3
# 118   test_98.jpg                1
# 119    test_9.jpg                3
#
# [120 rows x 2 columns]>

# %%
pred_mine = pd.read_csv('./prediction_result.csv', encoding='utf-8')

# %%
kg_score = []
mine_pred = []

for ans in score["predicted_label"]:
    kg_score.append(ans)

for ans in pred_mine["predicted_label"]:
    mine_pred.append(ans)

# %%
from sklearn import metrics
metrics.accuracy_score(score, pred_mine)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-7a85cb8caaf5> in <module>
#       1 from sklearn import metrics
# ----> 2 metrics.accuracy_score(score, pred_mine)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#      87
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/multiclass.py in type_of_target(y)
#     276         raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
#     277
# --> 278     if is_multilabel(y):
#     279         return "multilabel-indicator"
#     280
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/multiclass.py in is_multilabel(y)
#     169         )
#     170     else:
# --> 171         labels = np.unique(y)
#     172
#     173         return len(labels) < 3 and (
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     331         aux = ar[perm]
#     332     else:
# --> 333         ar.sort()
#     334         aux = ar
#     335     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'
